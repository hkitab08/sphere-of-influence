# %%
import os
from dotenv import load_dotenv
import tweepy

# Load the .env file
load_dotenv(dotenv_path='secrets.env')

# Access the API keys and tokens from environment variables
API_KEY = os.getenv('API_KEY')
API_SECRET = os.getenv('API_SECRET')
ACCESS_TOKEN = os.getenv('ACCESS_TOKEN')
ACCESS_TOKEN_SECRET = os.getenv('ACCESS_TOKEN_SECRET')

# Authenticate to Twitter
auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# Create the Tweepy API object
api = tweepy.API(auth)

# Now you can make requests to the Twitter API
print("Successfully authenticated")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/s3/_hbrgswx2k72nw__rm8cnm780000gn/T/ipykernel_42488/1798929524.py in <module>
#      13
#      14 # Authenticate to Twitter
# ---> 15 auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
#      16 auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
#      17
#
# /opt/anaconda3/lib/python3.8/site-packages/tweepy/auth.py in __init__(self, consumer_key, consumer_secret, access_token, access_token_secret, callback)
#     122             DeprecationWarning
#     123         )
# --> 124         super().__init__(consumer_key, consumer_secret, access_token,
#     125                          access_token_secret, callback)
#     126
#
# /opt/anaconda3/lib/python3.8/site-packages/tweepy/auth.py in __init__(self, consumer_key, consumer_secret, access_token, access_token_secret, callback)
#      29                  access_token_secret=None, callback=None):
#      30         if not isinstance(consumer_key, (str, bytes)):
# ---> 31             raise TypeError("Consumer key must be string or bytes, not "
#      32                             + type(consumer_key).__name__)
#      33         if not isinstance(consumer_secret, (str, bytes)):
#
# TypeError: Consumer key must be string or bytes, not NoneType

# %%
import os
from dotenv import load_dotenv

# Load the .env file
load_dotenv(dotenv_path='secrets.env')  # Adjust the path if necessary

# Get the API keys from environment variables
API_KEY = os.getenv('API_KEY')
API_SECRET = os.getenv('API_SECRET')
ACCESS_TOKEN = os.getenv('ACCESS_TOKEN')
ACCESS_TOKEN_SECRET = os.getenv('ACCESS_TOKEN_SECRET')

# Print the environment variables to check if they are set correctly
print("API_KEY:", API_KEY)
print("API_SECRET:", API_SECRET)
print("ACCESS_TOKEN:", ACCESS_TOKEN)
print("ACCESS_TOKEN_SECRET:", ACCESS_TOKEN_SECRET)

# Check if any variable is None
if None in [API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET]:
    print("Error: One or more environment variables are not set correctly.")
# Out:
# API_KEY: None
# API_SECRET: None
# ACCESS_TOKEN: None
# ACCESS_TOKEN_SECRET: None
# Error: One or more environment variables are not set correctly.
